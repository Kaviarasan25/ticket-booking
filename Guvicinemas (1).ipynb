# %%
# !pip install dnspython
# !pip install pymongo[srv]
# !pip install Pillow
# !pip install qrcode
# !pip install simple-colors
# Out:
# Requirement already satisfied: dnspython in /usr/local/lib/python3.7/dist-packages (2.2.1)
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.7/dist-packages (4.0.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pymongo[srv]) (2.2.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Requirement already satisfied: qrcode in /usr/local/lib/python3.7/dist-packages (7.3.1)
# Requirement already satisfied: simple-colors in /usr/local/lib/python3.7/dist-packages (0.1.5)

# %%
import pymongo
from pymongo import MongoClient
from PIL import Image
import qrcode
import matplotlib.pyplot as plt
import random
import io
import pandas as pd
from simple_colors import *
from os import name

# %%
client = pymongo.MongoClient("mongodb+srv://kaviarasangk5:12345@cluster0.qpure.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.GUVICINEMAS
records=db.details

# %%
docs=db.moviecollections
feilds=db.theatres
movies=db.list

movielist=[{"_id":1,"Movie":"Spiderman","CBFC":"U\A"},
   {"_id":2,"Movie":"Kgf 2","CBFC":"U\A"},
   {"_id":3,"Movie":"Pushpa","CBFC":"A"},
   {"_id":4,"Movie":"Valimai","CBFC":"U"},
   {"_id":5,"Movie":"Beast","CBFC":"U"}                                                                                                                                                  
   ]
theatrelist=[{"_id":1,"Theatre":"PVR","seat_availablity":20,"Timings":"Morning","Rating":"4"},
   {"_id":2,"Theatre":"PVR","seat_availablity":20,"Timings":"Evening","Rating":"4"},
   {"_id":3,"Theatre":"INOX","seat_availablity":20,"Timings":"Morning","Rating":"4.5"},
   {"_id":4,"Theatre":"INOX","seat_availablity":20,"Timings":"Evening","Rating":"4.5"},
   {"_id":5,"Theatre":"SATHYAM","seat_availablity":20,"Timings":"Morning","Rating":"3.5"},
   {"_id":6,"Theatre":"SATHYAM","seat_availablity":20,"Timings":"Evening","Rating":"3.5"}]
movies.insert_many(movielist)
feilds.insert_many(theatrelist)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-5-a391da967720> in <module>()
#      15    {"_id":5,"Theatre":"SATHYAM","seat_availablity":20,"Timings":"Morning","Rating":"3.5"},
#      16    {"_id":6,"Theatre":"SATHYAM","seat_availablity":20,"Timings":"Evening","Rating":"3.5"}]
# ---> 17 movies.insert_many(movielist)
#      18 feilds.insert_many(theatrelist)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     613         blk = _Bulk(self, ordered, bypass_document_validation)
#     614         blk.ops = [doc for doc in gen()]
# --> 615         blk.execute(write_concern, session=session)
#     616         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     617
#
# /usr/local/lib/python3.7/dist-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     457                 self.execute_no_results(sock_info, generator)
#     458         else:
# --> 459             return self.execute_command(generator, write_concern, session)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     350         client = self.collection.database.client
#     351         with client._tmp_session(session) as s:
# --> 352             client._retry_with_session(self.is_retryable, retryable_bulk, s, self)
#     353
#     354         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1272             retryable and self.options.retry_writes and session and not session.in_transaction
#    1273         )
# -> 1274         return self._retry_internal(retryable, func, session, bulk)
#    1275
#    1276     def _retry_internal(self, retryable, func, session, bulk):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1297                     session is not None and server.description.retryable_writes_supported
#    1298                 )
# -> 1299                 with self._get_socket(server, session) as sock_info:
#    1300                     max_wire_version = sock_info.max_wire_version
#    1301                     if retryable and not supports_session:
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _get_socket(self, server, session)
#    1134                 yield session._pinned_connection
#    1135                 return
# -> 1136             with server.get_socket(self.__all_credentials, handler=err_handler) as sock_info:
#    1137                 # Pin this session to the selected server or connection.
#    1138                 if in_txn and server.description.server_type in (
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in get_socket(self, all_credentials, handler)
#    1405             listeners.publish_connection_check_out_started(self.address)
#    1406
# -> 1407         sock_info = self._get_socket(all_credentials)
#    1408         if self.enabled_for_cmap:
#    1409             listeners.publish_connection_checked_out(self.address, sock_info.id)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in _get_socket(self, all_credentials)
#    1515                 else:  # We need to create a new connection
#    1516                     try:
# -> 1517                         sock_info = self.connect(all_credentials)
#    1518                     finally:
#    1519                         with self._max_connecting_cond:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in connect(self, all_credentials)
#    1371                 self.is_writable = sock_info.is_writable
#    1372
# -> 1373             sock_info.check_auth(all_credentials)
#    1374         except BaseException:
#    1375             sock_info.close_socket(ConnectionClosedReason.ERROR)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in check_auth(self, all_credentials)
#     846             for credentials in all_credentials.values():
#     847                 if credentials not in self.authset:
# --> 848                     self.authenticate(credentials)
#     849
#     850         # CMAP spec says to publish the ready event only after authenticating
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in authenticate(self, credentials)
#     863           - `credentials`: A MongoCredential.
#     864         """
# --> 865         auth.authenticate(credentials, self)
#     866         self.authset.add(credentials)
#     867         # negotiated_mechanisms are no longer needed.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/auth.py in authenticate(credentials, sock_info)
#     546     mechanism = credentials.mechanism
#     547     auth_func = _AUTH_MAP.get(mechanism)
# --> 548     auth_func(credentials, sock_info)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/auth.py in _authenticate_default(credentials, sock_info)
#     472             return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-256")
#     473         else:
# --> 474             return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-1")
#     475     else:
#     476         return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-1")
#
# /usr/local/lib/python3.7/dist-packages/pymongo/auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     238         ]
#     239     )
# --> 240     res = sock_info.command(source, cmd)
#     241
#     242     parsed = _parse_scram_response(res["payload"])
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     763                 unacknowledged=unacknowledged,
#     764                 user_fields=user_fields,
# --> 765                 exhaust_allowed=exhaust_allowed,
#     766             )
#     767         except (OperationFailure, NotPrimaryError):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     176                     sock_info.max_wire_version,
#     177                     allowable_errors,
# --> 178                     parse_write_concern_error=parse_write_concern_error,
#     179                 )
#     180     except Exception as exc:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     179         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     180
# --> 181     raise OperationFailure(errmsg, code, response, max_wire_version)
#     182
#     183
#
# OperationFailure: bad auth : Authentication failed., full error: {'ok': 0, 'errmsg': 'bad auth : Authentication failed.', 'code': 8000, 'codeName': 'AtlasError'}

# %%
from os import name
import pandas as pd
import random
def display_ticket(f):
  global name
  print()
  print()
  print()
  print( green('          GUVICINEMAS       ',['bold', 'underlined']))
  x=records.find({"NAME":name},{"_id":0,"NAME":1,"PH":1,"EMAIL":1})
  g=feilds.find({"_id":f},{"_id":0,"Theatre":1,"Timings":1})
  global fo
  fo={}
  for i in x:
    fo.update(i)
  for b in g:
    fo.update(b)
  for key, value in fo.items():
    print(key,  ' : ' , value)
  seatnum=[]
  for cv in range(count):
    seatnum.append(random.randint(0,20))
  print("seat  number: ",*seatnum)
  print("No of tickets:",count)
  qr(fo)

# %%
import qrcode
def qr(r):
  img = qrcode.make(r)
  type(img)  # qrcode.image.pil.PilImage
  img.save("some_file.png")
  from PIL import Image
  im=Image.open("some_file.png")
  plt.imshow(img)
  plt.axis('off')
  plt.show()
  im
qr('r')

# %%
global name
def ticketbooking():
  a=int(input("please select the theatre\n 1.PVR(Morning)\n 2.PVR(Evening)\n 3.INOX(Morning)\n 4.INOX(Evening)\n 5.SATHYAM(Morning)\n 6.SATHYAM(Evening)\n"))
  print()
  if a==1:
    global count
    count=int(input("How many tickets do you want?\n"))
    myquery={"_id":1}
    update={"$inc":{"seat_availablity":-count}}
    feilds.update_one(myquery,update)
    display_ticket(a)
  elif a==2:
    count=int(input("How many tickets do you want?\n"))
    myquery={"_id":2}
    update={"$inc":{"seat_availablity":-count}}
    feilds.update_one(myquery,update)
    display_ticket(a)
    
  elif a==3:
    count=int(input("How many tickets do you want?\n"))
    myquery={"_id":3}
    update={"$inc":{"seat_availablity":-count}}
    feilds.update_one(myquery,update)
    display_ticket(a)
    
  elif a==4:
    count=int(input("How many tickets do you want?\n"))
    myquery={"_id":4}
    update={"$inc":{"seat_availablity":-count}}
    feilds.update_one(myquery,update)
    display_ticket(a)
    
  elif a==5:
    count=int(input("How many tickets do you want?\n"))
    myquery={"_id":5}
    update={"$inc":{"seat_availablity":-count}}
    feilds.update_one(myquery,update)
    display_ticket(a)
    
  elif a==6:
    count=int(input("How many tickets do you want?"))
    myquery={"_id":6}
    update={"$inc":{"seat_availablity":-count}}
    feilds.update_one(myquery,update)
    print()
    print()
    print()
    display_ticket(a)

# %%
import pandas as pd
def selection():
  doj=movies.find()
  nee = pd.DataFrame.from_dict(doj)
  ggg=nee.set_index('_id')
  print(ggg)

  r=int(input("Please select the movie\n"))
  if r==1:
    name="Spiderman"
    ja= feilds.find()
    jaa = pd.DataFrame.from_dict(ja)
    jaj=jaa.set_index('_id')
    print(jaj)
    print()
    ticketbooking()
    print("Movie:Spiderman CBFC:U\A")
  elif r==2:
    name="Kgf 2"
    ja= feilds.find()
    jaa = pd.DataFrame.from_dict(ja)
    jaj=jaa.set_index('_id')
    print(jaj)
    print()
    ticketbooking()
    print("Movie:kgf 2 CBFC:U\A")
  elif r==3:
    name="pushpa"
    ja= feilds.find()
    jaa = pd.DataFrame.from_dict(ja)
    jaj=jaa.set_index('_id')
    print(jaj)
    print()
    ticketbooking()
    print("Movie:pushpa  CBFC:U\A")
  elif r==4:
    name="valimai"
    ja= feilds.find()
    jaa = pd.DataFrame.from_dict(ja)
    jaj=jaa.set_index('_id')
    print(jaj)
    print()
    ticketbooking()
    print("Movie:Valimai CBFC:U")
  elif r==5:
    name="Beast"
    ja= feilds.find()
    jaa = pd.DataFrame.from_dict(ja)
    jaj=jaa.set_index('_id')
    print(jaj)
    print()
    ticketbooking()
    print("Movie:Beast CBFC:U")
  else:
    print("wrong selection")
    selection()

# %%
def login():
  a=input("Enter your valid emaild id:")
  b=input("please enter your password:")
  jk={"EMAIL":a,"PW":b}
  X=records.find(jk,{"_id":1,"NAME":1,"Email":1,"PH":1,"PW":1,"image":1})
  a=[]
  for i in X:
    a.append(i)
    global name
    name=i.get("NAME")
    
  if not a:
    print("wrong username or password")
    login()
  else:
    print()
    print("Login Successfull")
    print()
    print("Hi {},Welcome to Guvicinemas!".format(name))
    import matplotlib.pyplot as plt
    image=records.find_one({"NAME":name})
    pil_img = Image.open(io.BytesIO(image['image']))
    plt.imshow(pil_img)
    plt.axis('off')
    plt.show()
    print()
    selection()

# %%
def register():
  global name
  name=input("Please enter your name:")
  Email=input("Enter your valid emaild id:")
  ph=input("Enter your phonenumber:")
  Pw=input("please enter your password:")
  image=input("Please provide the URL to upload your profile picture: ")
  im = Image.open(image)
  image_bytes = io.BytesIO()
  im.save(image_bytes, format='JPEG')
  A = {
   "NAME":name,
   "EMAIL":Email,
   "PH":ph,
   "PW":Pw,
   'image':image_bytes.getvalue()
   }
  records.insert_one(A)
  print()
  print("Registration successfull")
  print()
  print("Hi {},Welcome to Guvicinemas!".format(name))
  import matplotlib.pyplot as plt
  image=records.find_one({"NAME":name})
  pil_img = Image.open(io.BytesIO(image['image']))
  plt.axis('off')
  plt.imshow(pil_img)
  plt.show()
  print()
  selection()

# %%
def main():
  print("Welcome to Guvi cinemas!")
  print("Please confirm whether you want to 'Login' or 'Register':\n 1.Login\n 2.Register")
  poi=input()
  if poi=="1":
    login()
  elif poi=="2":
    register()
  else:
    print("Wrong selection.\n Please confirm whether you want to 'Login' or 'Register':\n 1.Login\n 2.Register")
    main()
main()
# Out:
# Welcome to Guvi cinemas!
# Please confirm whether you want to 'Login' or 'Register':
#  1.Login
#  2.Register
# 2
# Please enter your name:K G Kaviarasan
# Enter your valid emaild id:kaviarasands@gmail.com
# Enter your phonenumber:9876543210
# please enter your password:12345678
# Please provide the URL to upload your profile picture: /content/image.jpg
#
# Registration successfull
#
# Hi K G Kaviarasan,Welcome to Guvicinemas!
#          Movie CBFC
# _id
# 1    Spiderman  U\A
# 2        Kgf 2  U\A
# 3       Pushpa    A
# 4      Valimai    U
# 5        Beast    U
# Please select the movie
# 5
#      Theatre  seat_availablity  Timings Rating
# _id
# 1        PVR                16  Morning      4
# 2        PVR                15  Evening      4
# 3       INOX                18  Morning    4.5
# 4       INOX                16  Evening    4.5
# 5    SATHYAM                15  Morning    3.5
# 6    SATHYAM                17  Evening    3.5
#
# please select the theatre
#  1.PVR(Morning)
#  2.PVR(Evening)
#  3.INOX(Morning)
#  4.INOX(Evening)
#  5.SATHYAM(Morning)
#  6.SATHYAM(Evening)
# 2
#
# How many tickets do you want?
# 2
#
#
#
#           GUVICINEMAS
# NAME  :  K G Kaviarasan
# EMAIL  :  kaviarasands@gmail.com
# PH  :  9876543210
# Theatre  :  PVR
# Timings  :  Evening
# seat  number:  9 15
# No of tickets: 2
# Movie:Beast CBFC:U
